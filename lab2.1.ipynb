# %% [markdown]
# ## Exercise: Analyzing and Visualizing Data with Matplotlib, Pandas, and NumPy
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# - CRIM - per capita crime rate by town
# - ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# - INDUS - proportion of non-retail business acres per town.
# - CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# - NOX - nitric oxides concentration (parts per 10 million)
# - RM - average number of rooms per dwelling
# - AGE - proportion of owner-occupied units built prior to 1940
# - DIS - weighted distances to five Boston employment centres
# - RAD - index of accessibility to radial highways
# - TAX - full-value property-tax rate per $10,000
# - PTRATIO - pupil-teacher ratio by town
# - B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# - LSTAT - % lower status of the population
# - MEDV - Median value of owner-occupied homes in $1000's
#
# ### Part 1: Data Preparation
#
# In this part of the exercise, you will use Pandas and NumPy to load and preprocess data. For this exercise, we will use a dataset of housing prices in Boston.
#
# 1.  Download the Boston Housing dataset from [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data) and save it to your local computer.
# 2.  Load the dataset into a Pandas DataFrame and examine its contents. The dataset should have 506 rows and 14 columns.
# 3.  Use NumPy to calculate some basic statistics about the dataset, such as the mean, median, standard deviation, minimum, and maximum values of each column.
# 4.  Clean the dataset by removing any missing or invalid values. You can use Pandas' `dropna()` method for this.

# %%
# !pip install pandas yfinance matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (2.2.1)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\A507\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: yfinance in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.2.37)
# Requirement already satisfied: matplotlib in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.8.3)
# Requirement already satisfied: seaborn in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.13.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: html5lib>=1.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (1.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: requests>=2.31 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: webencodings in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\a507\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.31->yfinance) (3.6)

# %%
import pandas as pd 
#Load the dataset into a Pandas DataFrame
names = ['CRIM', 'ZN','INDUS', 'CHAS','NOX','RM', 'AGE', 'DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df=pd.read_csv('housing.data', delim_whitespace=True,header=None,names=names)
#Examine the contents pf the DataFrame
print(df.head())
print(df.shape)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)
# C:\Users\A507\AppData\Local\Temp\ipykernel_15024\114403532.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df=pd.read_csv('housing.data', delim_whitespace=True,header=None,names=names)

# %%
import numpy as np
mean=np.mean(df,axis=0)
median= np.median(df,axis=0)
std=np.std(df,axis=0)
minimum=np.min(df,axis=0)
maximum=np.max(df,axis=0)
#print("Mean\n",mean)
#print("Median\n",median)
#print('Standard deviation\n',std)
#print('Min\n',minimum)
print('Max\n',maximum)
# Out:
# Max
#  CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# MEDV        50.0000
# dtype: float64

# %% [markdown]
# ### Part 2: Data Visualization
#
# In this part of the exercise, you will use Matplotlib to create some visualizations of the housing data.
#
# 1.  Create a scatter plot of the housing prices (`MEDV`) versus the number of rooms (`RM`). Label the axes and add a title to the plot.
# 2.  Create a histogram of the housing prices (`MEDV`). Label the axes and add a title to the plot.
# 3.  Create a box plot of the housing prices (`MEDV`) grouped by the proximity to employment centers (`DIS`). Label the axes and add a title to the plot.

# %%
import matplotlib.pyplot as plt
#Scatter plot of housing prices vs number of rooms
plt.scatter(df['RM'],df['MEDV'])
plt.title('Housing prices vs Number of rooms')
plt.xlabel('Number of rooms')
plt.ylabel('Housing prices')
plt.show()

# %%
#Histogram of housing prices
plt.hist(df['MEDV'],bins=30)
plt.title('Housing prices histogram')
plt.xlabel('Housing prices')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot([df['MEDV'][df['DIS'] <= 2], df['MEDV'][df['DIS'] > 2]])

plt.xticks([1,2],['Near Employment Center','Far From Emploment Center'])
plt.title('Housing prices by proximity to the emp. center')
plt.xlabel('Proximity')
plt.ylabel('Housing prices')
plt.show()

# %% [markdown]
# ### Part 3: Data Analysis
#
# In this part of the exercise, you will use Pandas and NumPy to perform some basic data analysis on the housing data.
#
# 1.  Calculate the correlation coefficient between the housing prices (`MEDV`) and the number of rooms (`RM`) using NumPy's `corrcoef()` method.
# 2.  Calculate the mean housing price (`MEDV`) for each neighborhood (`CHAS`). You can use Pandas' `groupby()` method for this.
# 3.  Calculate the percentage of houses that have more than 7 rooms (`RM`). You can use Pandas' `value_counts()` method for this.

# %%
import numpy as np
corr = np.corrcoef(df['MEDV'], df['RM'])[0,1]
print(f"Correlation coefficient between housing prices and and the number of rooms {corr}")

mean_by_chas=df.groupby('ZN')['MEDV'].mean()
print(f'Mean housing price for each neighborhood:{mean_by_chas}')

percent_more_than_7=(df['RM']>7).value_counts(normalize=True)*100
print(f"Percentage of houses that have more than 7 rooms: {percent_more_than_7}")
# Out:
# Correlation coefficient between housing prices and and the number of rooms 0.6953599470715396
# Mean housing price for each neighborhood:ZN
# 0.0      20.473387
# 12.5     20.130000
# 17.5     33.000000
# 18.0     24.000000
# 20.0     35.466667
# 21.0     22.150000
# 22.0     25.320000
# 25.0     22.440000
# 28.0     22.833333
# 30.0     22.500000
# 33.0     31.525000
# 34.0     27.166667
# 35.0     23.066667
# 40.0     29.900000
# 45.0     33.433333
# 52.5     23.433333
# 55.0     25.700000
# 60.0     25.725000
# 70.0     25.433333
# 75.0     28.200000
# 80.0     27.400000
# 82.5     33.200000
# 85.0     23.900000
# 90.0     38.340000
# 95.0     41.575000
# 100.0    31.600000
# Name: MEDV, dtype: float64
# Percentage of houses that have more than 7 rooms: RM
# False    87.351779
# True     12.648221
# Name: proportion, dtype: float64

# %% [markdown]
# ### Part 4: Putting it all together
#
# In this final part of the exercise, you will use all three libraries to create a complete data analysis and visualization pipeline.
#
# 1.  Load the dataset and preprocess it as before.
# 2.  Create the scatter plot and histogram as before.
# 3.  Calculate the correlation coefficient between the housing prices and the number of rooms as before.
# 4.  Group the data by the proximity to employment centers and calculate the mean housing prices as before.
# 5.  Create a bar chart of the mean housing prices by proximity to employment centers. Label the axes and add a title to the plot.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
#Load the dataset into a Pandas DataFrame
names = ['CRIM', 'ZN','INDUS', 'CHAS','NOX','RM', 'AGE', 'DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']
df=pd.read_csv('housing.data', delim_whitespace=True,header=None,names=names)
#Examine the contents pf the DataFrame
print(df.head())
print(df.shape)

#Scatter plot of housing prices vs number of rooms
plt.scatter(df['RM'],df['MEDV'])
plt.title('Housing prices vs Number of rooms')
plt.xlabel('Number of rooms')
plt.ylabel('Housing prices')
plt.show()
# Out:
# C:\Users\A507\AppData\Local\Temp\ipykernel_15024\42240841.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df=pd.read_csv('housing.data', delim_whitespace=True,header=None,names=names)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)
